# %%
import torch
import pandas as pd
import torch

# %%
record = torch.load("./swin_predictions_pi.pt", weights_only=True).tolist()

record_df = pd.DataFrame(record, columns=["Accelerator", "Steering Wheel", "Brake"])
record_df.to_csv("./new_attention_pi.csv", index=False)

# %%
record = torch.load("./cnn300/predictions_cnn_300.pt", weights_only=True).tolist()

record_df = pd.DataFrame(record, columns=["Accelerator", "Brake", "Steering Wheel"])
record_df.to_csv("./predictions_cnn_300.csv", index=False)

# %%
record = torch.load("./cnnlstm300/predictions_cnn_300.pt", weights_only=True).tolist()

record_df = pd.DataFrame(record, columns=["Accelerator", "Brake", "Steering Wheel"])
record_df.to_csv("./predictions_cnnlstm_300.csv", index=False)
